# %%
# Exercício 1
# Calcular o volume de uma esfera, onde v = 4/3 * Pi * r³. Mostre o volume com 2 casas decimais.

# %%
# Exercício 2
# Mostrar a data e hora atual, no formato dd/mm/aaaa hh:MM:ss.

# %%
# Exercício 3
# Receber o primeiro e o último nome e imprimir em ordem reversa com um espaço entre eles.

# %%
# Exercício 4
# Receber uma sequência de números separados por vírgula e gerar uma lista e uma tupla com eles.

# %%
# Exercício 5
# Receber um nome de arquivo (nome e extensão) e imprimir somente a extensão.

# %%
# Exercício 6
# Imprimir a primeira e a última cor de uma lista de cores.

# %%
# Exercício 7
# Ler um valor (n) inteiro e escrever a soma de n + nn + nnn.

# %%
# Exercício 8
# Mostrar o calendário de um dado mês e ano.

# %%
# Exercício 9
# Calcular o número de dias entre duas datas (dd/mm/aaaa).

# %%
# Exercício 10
# Retornar a diferença entre um dado número e 17. Se o número for maior que 17,
# retorne o valor absoluto do dobro da diferença.

# %%
# Exercício 11
# Testar se um número está 100 unidades próximo de 1000 ou 2000.

# %%
# Exercício 12
# Imprimir n cópias de uma dada string.

# %%
# Exercício 13
# Verificar se uma string começa com 'ab'. Se começar, escreve a string,
# senão escreva a string com 'ab' na frente.

# %%
# Exercício 14
# Contar quantas vezes um determinado número aparece numa lista.
# O usuário fornece a lista de números (separados por vírgula)
# e depois fornece o número a ser comparado.

# %%
# Exercício 15
# Receber n (inteiro não negativo) e imprimir n vezes os dois primeiros caracteres de uma string dada.
# Se a string tiver menos de dois caracteres, imprime a string n vezes.

# %%
# Exercício 16
# Verificar se uma letra é vogal ou consoante.

# %%
# Exercício 17
# Concatenar todos os elementos de uma lista de strings.

# %%
# Exercício 18
# Concatenar todos os elementos de uma lista de inteiros.

# %%
# Exercício 19
# Imprimir o maior elemento de uma lista.

# %%
# Exercício 20
# Imprimir o segundo maior elemento de uma lista.

# %%
# Exercício 21
# Ler uma lista de números inteiros digitados pelo usuário (separados por vírgula)
# e imprimir separadamente os valores pares e depois os ímpares.

# %%
# Exercício 22
# Juntar duas listas (numa terceira), ordenar os valores e dizer seu tamanho.
